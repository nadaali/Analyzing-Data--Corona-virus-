# %%
import pandas as pd
import numpy as np

# %%
path="Corona2.csv"

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd

# %%
df.size
# Out:
# 0

# %%
import pandas as pd
df=pd.read_csv("Corona2.csv")

# %%
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region      Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2023-01-03 4:21  33.93911
# 1   NaN    NaN            NaN        Albania  2023-01-03 4:21  41.15330
# 2   NaN    NaN            NaN        Algeria  2023-01-03 4:21  28.03390
# 3   NaN    NaN            NaN        Andorra  2023-01-03 4:21  42.50630
# 4   NaN    NaN            NaN         Angola  2023-01-03 4:21 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     207627    7849     199778     NaN  Afghanistan
# 1  20.168300     333812    3595     330217     NaN      Albania
# 2   1.659600     271229    6881     264348     NaN      Algeria
# 3   1.521800      47751     165      47586     NaN      Andorra
# 4  17.873900     105095    1930     103165     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     533.356919             3.780337
# 1   11599.555220             1.076953
# ...

# %%
#1.Write a Python program to display first 5 rows from COVID-19 dataset.
#print the dataset information and check the missing values.
df.head(5)
# Out:
#    FIPS Admin2 Province_State Country_Region      Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2023-01-03 4:21  33.93911
# 1   NaN    NaN            NaN        Albania  2023-01-03 4:21  41.15330
# 2   NaN    NaN            NaN        Algeria  2023-01-03 4:21  28.03390
# 3   NaN    NaN            NaN        Andorra  2023-01-03 4:21  42.50630
# 4   NaN    NaN            NaN         Angola  2023-01-03 4:21 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     207627    7849     199778     NaN  Afghanistan
# 1  20.168300     333812    3595     330217     NaN      Albania
# 2   1.659600     271229    6881     264348     NaN      Algeria
# 3   1.521800      47751     165      47586     NaN      Andorra
# 4  17.873900     105095    1930     103165     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     533.356919             3.780337
# 1   11599.555220             1.076953
# ...

# %%
#2.Write a python program to replace all the missing values with
#Tobefound” for province column
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
#df.replace('NaN','Tobefound',inplace = True)
df['Admin2'].replace("NaN","Tobefound",inplace=True)
df.head(5)
# Out:
#    FIPS Admin2 Province_State Country_Region      Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2023-01-03 4:21  33.93911
# 1   NaN    NaN            NaN        Albania  2023-01-03 4:21  41.15330
# 2   NaN    NaN            NaN        Algeria  2023-01-03 4:21  28.03390
# 3   NaN    NaN            NaN        Andorra  2023-01-03 4:21  42.50630
# 4   NaN    NaN            NaN         Angola  2023-01-03 4:21 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     207627    7849     199778     NaN  Afghanistan
# 1  20.168300     333812    3595     330217     NaN      Albania
# 2   1.659600     271229    6881     264348     NaN      Algeria
# 3   1.521800      47751     165      47586     NaN      Andorra
# 4  17.873900     105095    1930     103165     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     533.356919             3.780337
# 1   11599.555220             1.076953
# ...

# %%
df
# Out:
#       FIPS Admin2 Province_State        Country_Region      Last_Update  \
# 0      NaN    NaN            NaN           Afghanistan  2023-01-03 4:21
# 1      NaN    NaN            NaN               Albania  2023-01-03 4:21
# 2      NaN    NaN            NaN               Algeria  2023-01-03 4:21
# 3      NaN    NaN            NaN               Andorra  2023-01-03 4:21
# 4      NaN    NaN            NaN                Angola  2023-01-03 4:21
# ...    ...    ...            ...                   ...              ...
# 4011   NaN    NaN            NaN    West Bank and Gaza  2023-01-03 4:21
# 4012   NaN    NaN            NaN  Winter Olympics 2022  2023-01-03 4:21
# 4013   NaN    NaN            NaN                 Yemen  2023-01-03 4:21
# 4014   NaN    NaN            NaN                Zambia  2023-01-03 4:21
# 4015   NaN    NaN            NaN              Zimbabwe  2023-01-03 4:21
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    FIPS  Admin2  Province_State  Country_Region  Last_Update    Lat  Long_  \
# 0  True    True            True           False        False  False  False
# 1  True    True            True           False        False  False  False
# 2  True    True            True           False        False  False  False
# 3  True    True            True           False        False  False  False
# 4  True    True            True           False        False  False  False
#
#    Confirmed  Deaths  Recovered  Active  Combined_Key  Incident_Rate  \
# 0      False   False      False    True         False          False
# 1      False   False      False    True         False          False
# 2      False   False      False    True         False          False
# 3      False   False      False    True         False          False
# 4      False   False      False    True         False          False
#
#    Case_Fatality_Ratio
# 0                False
# 1                False
# 2                False
# ...

# %%
df.isnull().sum()#FIND OUT ALL THE MISSING VALUES IN A DATASET
# Out:
# FIPS                    748
# Admin2                  744
# Province_State          179
# Country_Region            0
# Last_Update               0
# Lat                      91
# Long_                    91
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                 4016
# Combined_Key              0
# Incident_Rate            94
# Case_Fatality_Ratio      42
# dtype: int64

# %%
#Normalize the values for “Confirmed” column as per the z-score.
df['ZSCORE']= (df['Confirmed']-df['Confirmed'].mean())/df['Confirmed'].std()

# %%
df
# Out:
#       FIPS Admin2 Province_State        Country_Region      Last_Update  \
# 0      NaN    NaN            NaN           Afghanistan  2023-01-03 4:21
# 1      NaN    NaN            NaN               Albania  2023-01-03 4:21
# 2      NaN    NaN            NaN               Algeria  2023-01-03 4:21
# 3      NaN    NaN            NaN               Andorra  2023-01-03 4:21
# 4      NaN    NaN            NaN                Angola  2023-01-03 4:21
# ...    ...    ...            ...                   ...              ...
# 4011   NaN    NaN            NaN    West Bank and Gaza  2023-01-03 4:21
# 4012   NaN    NaN            NaN  Winter Olympics 2022  2023-01-03 4:21
# 4013   NaN    NaN            NaN                 Yemen  2023-01-03 4:21
# 4014   NaN    NaN            NaN                Zambia  2023-01-03 4:21
# 4015   NaN    NaN            NaN              Zimbabwe  2023-01-03 4:21
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# ...

# %%
df[df['ZSCORE']>2.5]
# Out:
#         FIPS       Admin2       Province_State  Country_Region  \
# 7        NaN          NaN                  NaN       Argentina
# 10       NaN          NaN      New South Wales       Australia
# 15       NaN          NaN             Victoria       Australia
# 17       NaN          NaN                  NaN         Austria
# 54       NaN          NaN         Minas Gerais          Brazil
# 57       NaN          NaN               Parana          Brazil
# 61       NaN          NaN    Rio Grande do Sul          Brazil
# 66       NaN          NaN            Sao Paulo          Brazil
# 188      NaN          NaN                  NaN         Czechia
# 191      NaN          NaN                  NaN         Denmark
# 217      NaN          NaN                  NaN          France
# 221      NaN          NaN    Baden-Wurttemberg         Germany
# 222      NaN          NaN               Bayern         Germany
# 227      NaN          NaN               Hessen         Germany
# ...

# %%
#Create bin values for “Death” column in the data set.

# %%
import pandas as pd
import numpy as np%matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

bins = np.linspace(min(df["Death"]), max(df["Death"]), 4)

#print(bins)
#groupnames=['low','medium','high']
# Out:
#   File "<ipython-input-38-99c6370611c8>", line 2
#     import numpy as np%matplotlib inline
#                       ^
# SyntaxError: invalid syntax

# %%
#Write a Python program to get the maximum number of confirmed,
#eaths, recovered and active cases of Novel Coronavirus (COVID-19)
#country wise

# %%
#df['Death'].max()
df2=df[['Confirmed','Death']] [df.Confirmed==df['Death'].max()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-8eeba75f5e90> in <cell line: 2>()
#       1 #df['Death'].max()
# ----> 2 df2=df[['Confirmed','Death']] [df.Confirmed==df['Death'].max()]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-0a2f0e416a85> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 covid_data['Active'] = covid_data['Confirmed'] - covid_data['Deaths'] - covid_data['Recovered']
#       3 result = covid_data.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered', 'Active'].sum().reset_index()
#       4 print(result)
#
# NameError: name 'covid_data' is not defined
